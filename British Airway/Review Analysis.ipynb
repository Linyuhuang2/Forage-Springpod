# %% [markdown]
# # Review Analysis
#
# ## Steps:
# * Data preprocessing
# * Sentiment analysis
# * Keyword extraction
# * Topic analysis
# * Satisfaction analysis
# * word cloud visualization
# * contrastive analysis

# %% [markdown]
# ## 1. Data proprocessing
# 从csv文件中读取数据。
# 数据清洗

# %%
# 下载需要的modules
import pandas as pd 
import re
# %pip install nltk


from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
print(nltk.data.path)
print(nltk.__version__)
nltk.download('wordnet')
# Out:
# Requirement already satisfied: nltk in e:\python\lib\site-packages (3.9.1)
# Requirement already satisfied: click in e:\python\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in e:\python\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in e:\python\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in e:\python\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\40118\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# ['C:\\Users\\40118/nltk_data', 'e:\\Python\\nltk_data', 'e:\\Python\\share\\nltk_data', 'e:\\Python\\lib\\nltk_data', 'C:\\Users\\40118\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data', 'C:\\Users\\40118\\AppData\\Roaming\\nltk_data']
# 3.9.1
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\40118\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
print(nltk.data.path)
# Out:
# ['C:\\Users\\40118/nltk_data', 'e:\\Python\\nltk_data', 'e:\\Python\\share\\nltk_data', 'e:\\Python\\lib\\nltk_data', 'C:\\Users\\40118\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data', 'C:\\Users\\40118\\AppData\\Roaming\\nltk_data']

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# 添加到 nltk.data.path 中
nltk.data.path.append(r'C:\Users\40118\AppData\Roaming\nltk_data')

try:
    nltk.data.find('tokenizers/punkt')
    print("punkt is installed successfully!")
except LookupError:
    print("punkt is not installed!")


import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet

# 运行词汇分词测试
sentence = "This is a test sentence."
tokens = word_tokenize(sentence)
print("Tokenized Sentence:", tokens)

# 测试 stopwords
stop_words = stopwords.words('english')
print("Stopwords:", stop_words[:10])  # 打印前10个停用词

# 测试 wordnet
synsets = wordnet.synsets("dog")
print("Synsets for 'dog':", synsets)
# Out:
# punkt is installed successfully!
# Tokenized Sentence: ['This', 'is', 'a', 'test', 'sentence', '.']
# Stopwords: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
# Synsets for 'dog': [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\40118\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\40118\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Data preprocessing

# Load .csv file
data = pd.read_csv(r'C:\Users\40118\OneDrive\Courses\unfiled project\virtural internship projects\British Airway\data\BA_reviews.csv')
print(data.head())

# Data cleaning
def preprocess_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove non-alphabetic characters
    text = text.lower()  # Transfer it into lowercase
    tokens = word_tokenize(text)  #分词
    tokens = [word for word in tokens if word not in stopwords.words('english')]  # 去掉停用词
    return ' '.join(tokens)

data['cleaned_review'] = data['reviews'].apply(preprocess_text)
print(data['cleaned_review'].head())
# Out:
#                                              reviews
# 0  ✅ Trip Verified |   British airways lost bags ...
# 1  ✅ Trip Verified | The check in process and rew...
# 2  ✅ Trip Verified |   We flew in November 2023, ...
# 3  ✅ Trip Verified | I left for London from Johan...
# 4  ✅ Trip Verified |   After an excellent flight ...
# 0    trip verified british airways lost bags lhr fo...
# 1    trip verified check process rewardloyalty prog...
# 2    trip verified flew november took long seek sat...
# 3    trip verified left london johannesburg decembe...
# 4    trip verified excellent flight cpt lhr return ...
# Name: cleaned_review, dtype: object

# %% [markdown]
# ## 2. 情感分析
# 目标：
# 分析评论的正面、负面或中性情感。
# 方法：
# 使用预训练的情感分析模型或工具包（如 TextBlob 或 VADER）。

# %%
print(data.columns)
# Out:
# Index(['reviews', 'cleaned_review'], dtype='object')

# %%
# %pip install textblob
import matplotlib.pyplot as plt
from textblob import TextBlob

# 计算情感得分
data['sentiment'] = data['cleaned_review'].apply(lambda x: TextBlob(x).sentiment.polarity)
print(data[['reviews', 'sentiment']].head())

# 简单分类为正面、负面和中性
data['sentiment_category'] = data['sentiment'].apply(lambda x: 'positive' if x > 0 else ('negative' if x < 0 else 'neutral'))
print(data['sentiment_category'].value_counts())

# 打印情感分类分布
print(data['sentiment_category'].value_counts())

# 可视化情感分布（饼图）
plt.figure(figsize=(6, 6))
data['sentiment_category'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['green', 'red', 'gray'])
plt.title('Sentiment Distribution')
plt.ylabel('')
plt.show()

# 或者使用条形图
plt.figure(figsize=(8, 5))
data['sentiment_category'].value_counts().plot.bar(color=['green', 'red', 'gray'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment Category')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# Requirement already satisfied: textblob in e:\python\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in e:\python\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in e:\python\lib\site-packages (from nltk>=3.8->textblob) (8.1.8)
# Requirement already satisfied: joblib in e:\python\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in e:\python\lib\site-packages (from nltk>=3.8->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in e:\python\lib\site-packages (from nltk>=3.8->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\40118\appdata\roaming\python\python313\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
#                                              reviews  sentiment
# 0  ✅ Trip Verified |   British airways lost bags ...  -0.066667
# 1  ✅ Trip Verified | The check in process and rew...  -0.308333
# 2  ✅ Trip Verified |   We flew in November 2023, ...  -0.056439
# 3  ✅ Trip Verified | I left for London from Johan...   0.044049
# 4  ✅ Trip Verified |   After an excellent flight ...   0.218618
# sentiment_category
# positive    627
# negative    354
# neutral      19
# Name: count, dtype: int64
# sentiment_category
# positive    627
# negative    354
# neutral      19
# Name: count, dtype: int64

# %% [markdown]
# ## 3. 关键词提取
# 目标：
# 提取高频关键词，分析旅客关心的重点。

# %%
# %pip install scikit-learn

from sklearn.feature_extraction.text import CountVectorizer

# 提取高频词
vectorizer = CountVectorizer(max_features=10)  # 取前10个高频词
X = vectorizer.fit_transform(data['cleaned_review'])
keywords = vectorizer.get_feature_names_out()
print("关键词:", keywords)
# Out:
# Requirement already satisfied: scikit-learn in e:\python\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in e:\python\lib\site-packages (from scikit-learn) (2.2.1)
# Requirement already satisfied: scipy>=1.6.0 in e:\python\lib\site-packages (from scikit-learn) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in e:\python\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\python\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# 关键词: ['ba' 'british' 'crew' 'flight' 'london' 'service' 'time' 'trip' 'us'
#  'verified']

# %% [markdown]
# ## 4. 主题分析
# 目标：
# 使用 LDA 或其他主题模型发现隐藏的评价主题。

# %%
# %pip install pyLDAvis --prefer-binary
import pyLDAvis
print(pyLDAvis.__version__)
# Out:
# Requirement already satisfied: pyLDAvis in e:\python\lib\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in e:\python\lib\site-packages (from pyLDAvis) (2.2.1)
# Requirement already satisfied: scipy in e:\python\lib\site-packages (from pyLDAvis) (1.15.0)
# Requirement already satisfied: pandas>=2.0.0 in e:\python\lib\site-packages (from pyLDAvis) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in e:\python\lib\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in e:\python\lib\site-packages (from pyLDAvis) (3.1.5)
# Requirement already satisfied: numexpr in e:\python\lib\site-packages (from pyLDAvis) (2.10.2)
# Requirement already satisfied: funcy in e:\python\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in e:\python\lib\site-packages (from pyLDAvis) (1.6.0)
# Requirement already satisfied: gensim in e:\python\lib\site-packages (from pyLDAvis) (0.10.1)
# Requirement already satisfied: setuptools in e:\python\lib\site-packages (from pyLDAvis) (75.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\40118\appdata\roaming\python\python313\site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\python\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\python\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\python\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: six>=1.2.0 in c:\users\40118\appdata\roaming\python\python313\site-packages (from gensim->pyLDAvis) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\python\lib\site-packages (from jinja2->pyLDAvis) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# 3.4.0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import pyLDAvis
import pyLDAvis.lda_model
pyLDAvis.enable_notebook()




# 移自定义停用词
custom_stop_words = ["us", "ba", "british", "london", "trip", "airway", "verified", "flight"]

# 计算词频矩阵，移除常见词
vectorizer = CountVectorizer(max_df=0.85, stop_words=custom_stop_words)
X = vectorizer.fit_transform(data['cleaned_review'])

# LDA 主题模型
lda = LatentDirichletAllocation(n_components=3, random_state=42)  # 主题数量增加到7，看看能不能分离细节
lda.fit(X)

# 输出主题关键词
terms = vectorizer.get_feature_names_out()
for idx, topic in enumerate(lda.components_):
    print(f"主题 {idx}: {[terms[i] for i in topic.argsort()[-10:]]}")

# pyLDAvis 可视化
vis = pyLDAvis.lda_model.prepare(lda, X, vectorizer)
pyLDAvis.display(vis)
# Out:
# 主题 0: ['cancelled', 'airport', 'airline', 'would', 'get', 'told', 'hours', 'customer', 'airways', 'service']
# 主题 1: ['seats', 'time', 'cabin', 'seat', 'business', 'crew', 'food', 'service', 'class', 'good']
# 主题 2: ['experience', 'seats', 'good', 'economy', 'seat', 'service', 'time', 'cabin', 'food', 'crew']
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el563623905632348961276722137" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el563623905632348961276722137_data = {"mdsDat": {"x": [0.14113427004176612, -0.0662869463203036, -0.07484732372146255], "y": [0.0022546792721474477, -0.056886419815719264, 0.05463174054357179], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [49.958699836150195, 34.04685554408883, 15.994444619760978]}, "tinfo": {"Term": ["crew", "good", "food", "cabin", "class", "customer", "lounge", "cancelled", "seat", "economy", "club", "told", "booked", "business", "seats", "friendly", "meal", "comfortable", "refund", "time", "drinks", "aircraft", "premium", "call", "boarding", "phone", "entertainment", "water", "great", "small", "cancelled", "refund", "phone", "email", "hotel", "voucher", "lost", "compensation", "claim", "cancel", "response", "booked", "weeks", "original", "counter", "calling", "cancellation", "vouchers", "sent", "leave", "layover", "emails", "august", "refunded", "message", "booking", "rebook", "representative", "expenses", "details", "customer", "call", "tickets", "told", "connecting", "rebooked", "speak", "help", "change", "day", "received", "travel", "website", "ticket", "never", "airport", "online", "hours", "days", "airways", "finally", "airline", "get", "luggage", "later", "would", "another", "next", "could", "fly", "service", "flights", "back", "got", "heathrow", "one", "even", "staff", "time", "hour", "plane", "smooth", "priority", "gates", "galleries", "beef", "champagne", "lounge", "facing", "chaotic", "fas", "doco", "pie", "north", "climb", "eight", "organised", "cpt", "overcrowded", "galley", "cooked", "turkish", "range", "handling", "turkey", "buffet", "yang", "quieter", "refurbished", "supply", "kitchen", "sausage", "quick", "excellent", "chaos", "rows", "efficient", "club", "lounges", "good", "brought", "legs", "breakfast", "class", "seated", "choices", "seating", "boarding", "overall", "cabin", "dinner", "food", "business", "drinks", "europe", "crew", "aircraft", "served", "meal", "seat", "seats", "nice", "fine", "time", "service", "passengers", "great", "first", "economy", "staff", "well", "check", "one", "board", "minutes", "really", "experience", "would", "get", "back", "dated", "vegas", "wir", "lowcost", "und", "plate", "priced", "buenos", "aires", "neighbour", "lgw", "pod", "odd", "hesitate", "disembarkation", "dubrovnik", "sale", "socks", "cake", "nose", "euroflyer", "footrest", "weak", "newer", "warmth", "dime", "nassau", "padding", "content", "compelled", "pillow", "finish", "masks", "complimentary", "crews", "kit", "step", "basic", "warm", "entertainment", "snack", "water", "crew", "friendly", "premium", "comfortable", "economy", "inflight", "cabin", "food", "best", "world", "product", "uncomfortable", "seat", "experience", "generous", "small", "seats", "meal", "time", "good", "great", "really", "leg", "service", "offered", "passengers", "drinks", "one", "class", "business", "aircraft", "flights", "airways", "like", "airline", "new", "even"], "Freq": [401.0, 383.0, 389.0, 324.0, 396.0, 294.0, 173.0, 213.0, 400.0, 215.0, 203.0, 279.0, 188.0, 370.0, 344.0, 112.0, 162.0, 102.0, 131.0, 493.0, 121.0, 166.0, 115.0, 147.0, 237.0, 116.0, 84.0, 98.0, 131.0, 102.0, 212.5099442090315, 130.7151704508162, 115.78811429558161, 91.57581495278987, 87.84382042288226, 92.42220204815185, 77.47181536814495, 60.84879473265776, 58.982380628675635, 50.59915974435208, 49.65293426636138, 185.76837179872803, 60.52693080651591, 40.24161777681407, 34.73409424272785, 31.04658352226661, 31.04403256735487, 31.036985489134306, 63.605910333846595, 26.369680273766047, 26.367972580121567, 26.36663061546891, 27.276348777945458, 26.355396427811726, 25.448450003238523, 105.26239878773737, 56.09140812355161, 23.529406705303444, 20.797531592882823, 20.797270349755237, 285.19367470161984, 142.72150324932872, 57.711256463907645, 265.86353422720555, 95.84891556620447, 49.26323991405189, 41.29060494191877, 119.87073586067125, 100.65518206651319, 157.95092427992734, 86.33126423912888, 121.81051216016903, 79.73143096216552, 112. ...

# %% [markdown]
# ## 5. 满意度分析
# 目标：
# 将情感分析的结果转化为评分，统计总体满意度。

# %%
# 满意度评分转换（将情感得分转化为1-5分制）
data['satisfaction_score'] = data['sentiment'].apply(lambda x: round((x + 1) * 2.5, 2))  # -1~1映射到1~5
print(data[['reviews', 'satisfaction_score']].head())
# Out:
#                                              reviews  satisfaction_score
# 0  ✅ Trip Verified |   British airways lost bags ...                2.33
# 1  ✅ Trip Verified | The check in process and rew...                1.73
# 2  ✅ Trip Verified |   We flew in November 2023, ...                2.36
# 3  ✅ Trip Verified | I left for London from Johan...                2.61
# 4  ✅ Trip Verified |   After an excellent flight ...                3.05

# %% [markdown]
# ## 6. 词云可视化
# 目标：
# 直观展示评价中的高频词。

# %%
# %pip install --upgrade kiwisolver
# Out:
# Requirement already satisfied: kiwisolver in e:\python\lib\site-packages (1.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
#%pip uninstall matplotlib
#%pip install matplotlib

#%pip install wordcloud

#from wordcloud import WordCloud
#import matplotlib.pyplot as plt

# 生成词云
all_text = " ".join(data['cleaned_review'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# e:\Python\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %% [markdown]
# ## 7. 对比分析
# 目标：
# 对不同航空公司、不同时间段的评价进行对比。
# 示例：对两家航空公司的评价进行比较

# %%
# 比较不同情感分类的平均满意度
comparison = data.groupby('sentiment_category')['satisfaction_score'].mean()
print(comparison)

# 可视化对比
comparison.plot(kind='bar', color=['red', 'green', 'blue'], title='Average Satisfaction Score by Sentiment Category')
plt.ylabel('Average Satisfaction Score')
plt.show()
# Out:
# sentiment_category
# negative    2.141610
# neutral     2.500000
# positive    2.950271
# Name: satisfaction_score, dtype: float64
